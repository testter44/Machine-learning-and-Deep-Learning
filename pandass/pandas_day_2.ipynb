# %%
import pandas as pd

df = pd.read_csv("new_data.csv")
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60  110.0       130     409.1
# 1        60  117.0       145     479.0
# 2        60  103.0       135     340.0
# 3        45  109.0       175     282.4
# 4        45  117.0       148     406.0

# %%
df.describe() # prints the summary statistics of all numeric columns
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  167.000000  169.000000   164.000000
# mean    63.798817  107.628743  133.686391   377.426829
# std     42.308755   14.520650   17.763388   265.960859
# min     15.000000   80.000000   45.000000    50.300000
# 25%     45.000000  100.000000  124.000000   252.725000
# 50%     60.000000  105.000000  131.000000   320.700000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df.describe(percentiles=[0.3, 0.5, 0.7])  # summary statistics with specific percentiles
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  167.000000  169.000000   164.000000
# mean    63.798817  107.628743  133.686391   377.426829
# std     42.308755   14.520650   17.763388   265.960859
# min     15.000000   80.000000   45.000000    50.300000
# 30%     45.000000  100.000000  126.000000   270.760000
# 50%     60.000000  105.000000  131.000000   320.700000
# 70%     60.000000  110.000000  138.600000   379.300000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df.describe().T  # transpose of rows and columns
# Out:
#           count        mean         std   min      25%    50%    75%     max
# Duration  169.0   63.798817   42.308755  15.0   45.000   60.0   60.0   300.0
# Pulse     167.0  107.628743   14.520650  80.0  100.000  105.0  111.0   159.0
# Maxpulse  169.0  133.686391   17.763388  45.0  124.000  131.0  141.0   184.0
# Calories  164.0  377.426829  265.960859  50.3  252.725  320.7  387.6  1860.4

# %%
df.shape # gives the number of rows and columns
# Out:
# (169, 4)

# %%
df.shape[0]  # number of rows only
# Out:
# 169

# %%
df.shape[1]  # number of columns only
# Out:
# 4

# %%
# gives name of column only
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
#can be converted into list using list() function  
list(df.columns)
# Out:
# ['Duration', 'Pulse', 'Maxpulse', 'Calories']

# %% [markdown]
# <b>Note:</b>  isnull() method checks if there is null value

# %%
#check null value
df.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
# use sum() to find sum of null values on each column
df.isnull().sum()
# Out:
# Duration    0
# Pulse       2
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
# double sum provides total null values
df.isnull().sum().sum()
# Out:
# 7

# %% [markdown]
# <h3 style="color:blue;"> Slicing and Extracting Data in pandas </h3>

# %% [markdown]
# <h4 style="color:blue;"> Working in columns </h4>

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60  110.0       130     409.1
# 1        60  117.0       145     479.0
# 2        60  103.0       135     340.0
# 3        45  109.0       175     282.4
# 4        45  117.0       148     406.0

# %%
#select a single column
df['Maxpulse']
# Out:
# 0      130
# 1      145
# 2      135
# 3      175
# 4      148
#       ...
# 164    140
# 165    145
# 166    145
# 167    150
# 168    150
# Name: Maxpulse, Length: 169, dtype: int64

# %%
#select a double or more columns
df[['Duration', 'Pulse']]
# Out:
#      Duration  Pulse
# 0          60  110.0
# 1          60  117.0
# 2          60  103.0
# 3          45  109.0
# 4          45  117.0
# ..        ...    ...
# 164        60  105.0
# 165        60  110.0
# 166        60  115.0
# 167        75  120.0
# 168        75  125.0
#
# [169 rows x 2 columns]

# %% [markdown]
# <h4 style="color:blue;"> Working in rows </h4>

# %%
#select a single row
df[df.index==56]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 56        60  118.0       121     413.0

# %% [markdown]
# <b>NOTE:</b> two or more rows can be obtained by .isin() method instead of a == operator

# %%
#selecting two or more rows using [ ] 
df[df.index.isin(range(5,10))]
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 5        60  102.0        45     300.0
# 6        60  110.0       136     374.0
# 7        45  104.0       134     253.3
# 8        30  109.0       133     195.1
# 9        60   98.0       124     269.0

# %% [markdown]
# <h4 style="color:blue;"> Using .loc[] and .iloc[] to fetch rows </h4>

# %%
df.loc[1]
# Out:
# Duration     60.0
# Pulse       117.0
# Maxpulse    145.0
# Calories    479.0
# Name: 1, dtype: float64

# %% [markdown]
# <b>REMEMBER:</b> .loc[] returns a pandas Series instead of a DataFrame

# %%
df.loc[10:20]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 10        60  103.0       147     329.3
# 11        60  100.0       120     250.7
# 12        60    NaN       128     345.3
# 13        60  104.0       132     379.3
# 14        60  104.0       132     379.3
# 15        60  104.0       132     379.3
# 16        60  100.0       120     300.0
# 17        45   90.0       112       NaN
# 18        60  103.0       123     323.0
# 19        45   97.0       125     243.0
# 20        52  108.0       131     364.2

# %%
df.iloc[10]
# Out:
# Duration     60.0
# Pulse       103.0
# Maxpulse    147.0
# Calories    329.3
# Name: 10, dtype: float64

# %%
df.iloc[10:30]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 10        60  103.0       147     329.3
# 11        60  100.0       120     250.7
# 12        60    NaN       128     345.3
# 13        60  104.0       132     379.3
# 14        45  104.0       132     379.3
# 15        60  104.0       132     379.3
# 16        60  100.0       120     300.0
# 17        45   90.0       112       NaN
# 18        60  103.0       123     323.0
# 19        45   97.0       125     243.0
# 20        45  108.0       131     364.2
# 21        45  100.0       119     282.0
# 22        60  130.0       101     300.0
# 23        45  105.0       132     246.0
# 24        60  102.0       126     334.5
# 25        60  100.0       120     250.0
# 26        60   92.0       118     241.0
# 27        60  103.0       132       NaN
# 28        60  100.0       132     280.0
# 29        60  102.0       129     380.3

# %%
df.loc[[10, 20, 30, 45]]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 10        60  103.0       147     329.3
# 20        52  108.0       131     364.2
# 30        60   92.0       115     243.0
# 45        60   99.0       119     273.0

# %%
df.iloc[[10, 20, 30]]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 10        60  103.0       147     329.3
# 20        52  108.0       131     364.2
# 30        60   92.0       115     243.0

# %%
df.loc[100:110, ['Duration', 'Maxpulse']]
# Out:
#      Duration  Maxpulse
# 100        20       112
# 101        90       110
# 102        90       100
# 103        90       100
# 104        30       108
# 105        30       128
# 106       180       120
# 107        30       120
# 108        90       120
# 109       210       184
# 110        60       124

# %%
# df1.to_json("modified.json")

# %%
df.iloc[5:10, :2]
# Out:
#    Duration  Pulse
# 5        60  102.0
# 6        60  110.0
# 7        45  104.0
# 8        30  109.0
# 9        60   98.0

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60  110.0       130     409.1
# 1        60  117.0       145     479.0
# 2        60  103.0       135     340.0
# 3        45  109.0       175     282.4
# 4        45  117.0       148     406.0
# 5        60  102.0        45     300.0
# 6        60  110.0       136     374.0
# 7        45  104.0       134     253.3
# 8        30  109.0       133     195.1
# 9        60   98.0       124     269.0

# %%
df = df.loc[df['Duration']==60, ['Duration']] = 12

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          12  110.0       130     409.1
# 1          12  117.0       145     479.0
# 2          12  103.0       135     340.0
# 3          45  109.0       175     282.4
# 4          45  117.0       148     406.0
# ..        ...    ...       ...       ...
# 164        12  105.0       140     290.8
# 165        12  110.0       145     300.0
# 166        12  115.0       145     310.2
# 167        75  120.0       150     320.4
# 168        75  125.0       150     330.4
#
# [169 rows x 4 columns]

# %%
df.iloc[5:10, :4]
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 5        60  102.0       148     300.0
# 6        80  110.0       136     374.0
# 7        45  104.0       134     253.3
# 8        30  109.0       133     195.1
# 9        60   98.0       124     269.0

# %% [markdown]
# <h4 style="color:blue;"> Conditional slicing </h4>
#
# pandas lets you filter data by conditions over row/column values

# %%
df[df.Duration == 12]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          12  110.0       130     409.1
# 1          12  117.0       145     479.0
# 2          12  103.0       135     340.0
# 5          12  102.0        45     300.0
# 6          12  110.0       136     374.0
# ..        ...    ...       ...       ...
# 157        12  100.0       120     270.4
# 158        12  114.0       150     382.8
# 164        12  105.0       140     290.8
# 165        12  110.0       145     300.0
# 166        12  115.0       145     310.2
#
# [78 rows x 4 columns]

# %%
# displays 'Pulse', 'Maxpulse', 'Calories' whose 'Duration' is grater than 75
df.loc[df['Duration'] > 75, ['Pulse', 'Maxpulse', 'Calories']]
# Out:
#      Pulse  Maxpulse  Calories
# 6    110.0       136     374.0
# 51   123.0       146     643.1
# 60   108.0       160    1376.0
# 61   110.0       137    1034.4
# 62   109.0       135     853.0
# 65    90.0       130     800.4
# 66   105.0       135     873.4
# 67   107.0       130     816.0
# 69   108.0       143    1500.2
# 70    97.0       129    1115.0
# 72   100.0       127     700.0
# 73    97.0       127     953.2
# 75    98.0       125     563.2
# 78   100.0       130     500.4
# 79   100.0       131    1729.0
# 83   100.0       130     500.0
# 87   100.0       157    1000.1
# 90   101.0       127     600.1
# 99    93.0       124     604.1
# 101   90.0       110     500.0
# 102   90.0       100     500.0
# 103   90.0       100     500.4
# 106   90.0       120     800.3
# 108   90.0       120     500.3
# 109  137.0       184    1860.4
# 128   99.0       125     466.4

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        12  110.0       130     409.1
# 1        12  117.0       145     479.0
# 2        12  103.0       135     340.0
# 3        45  109.0       175     282.4
# 4        45  117.0       148     406.0

# %%
#rename columns 

df1.rename(columns = {'Calories':'Cal'}, inplace = True)
df1.head()
# Out:
#    Duration  Pulse  Maxpulse    Cal
# 0        12  110.0       130  409.1
# 1        12  117.0       145  479.0
# 2        12  103.0       135  340.0
# 3        45  109.0       175  282.4
# 4        45  117.0       148  406.0

# %%
df1.columns = ['Duration', 'Pulse', 'Max', 'Calories']
df1.head()
# Out:
#    Duration  Pulse  Max  Calories
# 0        12  110.0  130     409.1
# 1        12  117.0  145     479.0
# 2        12  103.0  135     340.0
# 3        45  109.0  175     282.4
# 4        45  117.0  148     406.0
